# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Carregar os dados
df = pd.read_csv('dataset_modificado.csv')
df.sample(10)
# Out:
#         id dia_da_semana horario_de_pico operacao_normal estacao_de_entrada  \
# 1667  1668        Quarta             Sim             Não              Ceasa
# 472    473         Terça             Sim             Sim            Itapevi
# 905    906       Segunda             Sim             Não       Antônio João
# 510    511        Quarta             Sim             Sim  Domingo de Moraes
# 275    276         Terça             Sim             Não            Itapevi
# 745    746         Sexta             Não             Sim           Quitaúna
# 1232  1233        Quarta             Sim             Sim         Jurubatuba
# 1423  1424        Quinta             Sim             Sim          Autódromo
# 349    350       Segunda             Sim             Não             Osasco
# 1769  1770        Quarta             Não             Não            Socorro
#
#                     sentido esta_chovendo  lotacao_1_min_5_max  linha_8  \
# ...

# %%
# Sim vira 1, Não vira 0
df['horario_de_pico'] = df['horario_de_pico'].replace({
    'Sim':1,
    'Não':0,
})

# Sim vira 1, Não vira 0
df['operacao_normal'] = df['operacao_normal'].replace({
    'Sim':1,
    'Não':0,
})

# Sim vira 1, Não vira 0
df['esta_chovendo'] = df['esta_chovendo'].replace({
    'Sim':1,
    'Não':0,
})

# Sim vira 1, Não vira 0
df['dia_da_semana'] = df['dia_da_semana'].replace({
    'Segunda':1,
    'Terça':2,
    'Quarta':3,
    'Quinta':4,
    'Sexta':5,
    'Sábado':6,
    'Domingo':0,
})

df.sample(10)
# Out:
# C:\Users\rbeze\AppData\Local\Temp\ipykernel_16784\102343214.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['horario_de_pico'] = df['horario_de_pico'].replace({
# C:\Users\rbeze\AppData\Local\Temp\ipykernel_16784\102343214.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['operacao_normal'] = df['operacao_normal'].replace({
# ...

# %%
# Estação de entrada para numero
df['estacao_de_entrada'] = df['estacao_de_entrada'].replace({
    'Amador Bueno':1,
    'Antônio João':2,
    'Autódromo':3,
    'Barueri':4,
    'Berrini':5,
    'Carapicuíba':6,
    'Cidade Jardim':7,
    'Ceasa':8,
    'Cidade Universitária':9,
    'Com. Sampaio':10,
    'Domingo de Moraes':11,
    'Eng. Cardoso':12,
    'Gen. Miguel Costa':13,
    'Grajau':14,
    'Granja Julieta':15,
    'Hebraica Rebouças':16,
    'Imperatriz Leopoldina':17,
    'Itapevi':18,
    'Jandira':19,
    'Jardim Belval':20,
    'Jardim Silveira':21,
    'João Dias':22,
    'Jurubatuba':23,
    'Júlio Prestes':24,
    'Lapa':25,
    'Mendes Vila Natal':26,
    'Morumbi':27,
    'Osasco':28,
    'Palmeiras Barra Funda':29,
    'Pinheiros':30,
    'Pres. Altino':31,
    'Primavera Interlagos':32,
    'Quitaúna':33,
    'Sagrado Coração':34,
    'Santa Rita':35,
    'Santa Terezinha':36,
    'Santo Amaro':37,
    'Socorro':38,
    'Vila Olímpia':39,
    'Villa-Lobos Jaguaré':40,
})

# Sentido para numero
df['sentido'] = df['sentido'].replace({
    'Grajaú':1,
    'Itapevi':2,
    'Osasco':3,
    'Palmeiras Barra Funda':4,
})

df.sample(10)
# Out:
# C:\Users\rbeze\AppData\Local\Temp\ipykernel_16784\2892338469.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['estacao_de_entrada'] = df['estacao_de_entrada'].replace({
# C:\Users\rbeze\AppData\Local\Temp\ipykernel_16784\2892338469.py:46: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['sentido'] = df['sentido'].replace({
#         id  dia_da_semana  horario_de_pico  operacao_normal  \
# 1242  1243              5                1                1
# 680    681              1                1                1
# ...

# %%
# Separando as variáveis
X = df.drop(columns=['linha_8', 'linha_9'])
y_azul = df['linha_8']
y_vermelha = df['linha_9']

# %%
# Divisão de treino e teste
X_train, X_test, y_azul_train, y_azul_test = train_test_split(X, y_azul, test_size=0.2, random_state=42)
_, _, y_vermelha_train, y_vermelha_test = train_test_split(X, y_vermelha, test_size=0.2, random_state=42)

# %%
# Treinando o modelo para linha azul
modelo_azul = LinearRegression()
modelo_azul.fit(X_train, y_azul_train)
# Out:
# LinearRegression()

# %%
# Treinando o modelo para linha vermelha
modelo_vermelha = LinearRegression()
modelo_vermelha.fit(X_train, y_vermelha_train)
# Out:
# LinearRegression()

# %%
# Exibindo interceptos e coeficientes
print("Modelo Linha Azul:")
print(f"Intercepto: {modelo_azul.intercept_}")
print(f"Coeficientes: {modelo_azul.coef_}")

print("\nModelo Linha Vermelha:")
print(f"Intercepto: {modelo_vermelha.intercept_}")
print(f"Coeficientes: {modelo_vermelha.coef_}")
# Out:
# Modelo Linha Azul:
# Intercepto: 8.468493675588947
# Coeficientes: [-0.00696811  0.06141273  3.13790517 -0.17582182 -0.01432655  0.56367034
#  -0.06103679  0.04088491]
#
# Modelo Linha Vermelha:
# Intercepto: -3.2465277990872963
# Coeficientes: [ 0.00708724 -0.06686863  3.32299041  0.16336701  0.0244342  -0.62431857
#   0.0302968  -0.01005188]

# %%
# Cálculo do erro médio quadrático (MSE)
mse_azul = mean_squared_error(y_azul_test, modelo_azul.predict(X_test))
mse_vermelha = mean_squared_error(y_vermelha_test, modelo_vermelha.predict(X_test))

print(f"\nMSE Linha Azul: {mse_azul}")
print(f"MSE Linha Vermelha: {mse_vermelha}")
# Out:
# MSE Linha Azul: 8.927735347515533
# MSE Linha Vermelha: 8.73527414724156

# %%
# Serializando os modelos
with open('modelo_azul.pkl', 'wb') as f:
    pickle.dump(modelo_azul, f)

with open('modelo_vermelha.pkl', 'wb') as f:
    pickle.dump(modelo_vermelha, f)
